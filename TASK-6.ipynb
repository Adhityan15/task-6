# %%
from io import IncrementalNewlineDecoder
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("disney_plus_titles.csv")
df.head()
# Out:
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1368 non-null   object
#  1   type          1368 non-null   object
#  2   title         1368 non-null   object
#  3   director      928 non-null    object
#  4   cast          1194 non-null   object
#  5   country       1193 non-null   object
#  6   date_added    1365 non-null   object
#  7   release_year  1368 non-null   int64
#  8   rating        1366 non-null   object
#  9   duration      1368 non-null   object
#  10  listed_in     1368 non-null   object
#  11  description   1368 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 128.4+ KB

# %%
#Finding the count of NULL values
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        440
# cast            174
# country         175
# date_added        3
# release_year      0
# rating            2
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
#A Overal Analysis of data
sns.pairplot(df)

# %%
df.hist(bins=100, grid = False,figsize=(8,6));

# %%
df["type"].value_counts()
# Out:
# type
# Movie      991
# TV Show    377
# Name: count, dtype: int64

# %%
sns.pairplot(df)

# %%
# 1 type of shows 
df["type"].value_counts()
# Out:
# type
# Movie      991
# TV Show    377
# Name: count, dtype: int64

# %%
df.type.value_counts().plot(kind='bar',figsize=(6,5), color=('red','green','blue','yellow','violet','seagreen','orange','salmon'))
plt.xlabel('type')
plt.ylabel("type of movies")
plt.title("Number of movie types")
plt.show()

# %%
#2 no of show realse year
df.release_year.value_counts().plot(kind='bar',figsize=(26,10))
plt.xlabel('relase year')
plt.ylabel("Number of show")
plt.title("year")
plt.xticks(rotation=90)
plt.show()

# %%
#3 total no of unique 
num_genres = df['listed_in'].nunique()
print("Number of unique genres:", num_genres)
# Out:
# Number of unique genres: 317

# %%
df.listed_in.value_counts()
# Out:
# listed_in
# Animation, Comedy, Family                120
# Action-Adventure, Animation, Comedy       75
# Action-Adventure, Animation, Kids         45
# Animals & Nature, Documentary, Family     40
# Action-Adventure, Animation, Family       40
#                                         ...
# Animation, Documentary, Family             1
# Action-Adventure, Crime, Fantasy           1
# Comedy, Coming of Age, Medical             1
# Drama, Family, Historical                  1
# Animation, Family, Mystery                 1
# Name: count, Length: 317, dtype: int64

# %%
df.listed_in.value_counts().plot(kind='line',figsize=(32,9))
plt.show()

# %%
#4 release by runtime
df.groupby('release_year')['duration'].value_counts()
# Out:
# release_year  duration
# 1928          8 min       1
# 1932          8 min       2
#               7 min       1
# 1933          9 min       2
#               8 min       1
#                          ..
# 2021          66 min      1
#               7 min       1
#               80 min      1
#               87 min      1
#               95 min      1
# Name: count, Length: 884, dtype: int64

# %%
df.groupby('release_year')['duration'].nunique().plot(kind='bar',figsize=(32,10))
plt.title(" Movies of Varying runtime VS Year")
plt.xlabel("release_year")
plt.ylabel("Count of Movies with different runtime")
plt.show()
